# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.747875 -2.226477 -2.304536
# b       NaN       NaN       NaN
# c -0.037882  1.039645 -2.409466
# d -0.981317 -0.290823 -0.555292
# e       NaN       NaN       NaN
# f  1.453359 -1.444030  0.782017
#
#
# Dropped DataFrame
#          one       two     three
# a -0.747875 -2.226477 -2.304536
# c -0.037882  1.039645 -2.409466
# d -0.981317 -0.290823 -0.555292
# f  1.453359 -1.444030  0.782017

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  1.169733  0.121735 -1.310401
# b       NaN       NaN       NaN
# c -0.533639 -0.229065 -0.344637
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  1.169733  0.121735 -1.310401
# b  0.000000  0.000000  0.000000
# c -0.533639 -0.229065 -0.344637

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.047888  0.852115 -0.448080
# b       NaN       NaN       NaN
# c  0.014253  0.930999  0.133661
# d -1.015061  0.389716 -1.820405
# e       NaN       NaN       NaN
# f -1.494646 -0.356565 -0.962828
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.255923 -0.892860 -2.929329
# b       NaN       NaN       NaN
# c  0.980613 -0.352598 -0.043042
# d -2.241967  0.884888  0.488211
# e       NaN       NaN       NaN
# f -0.698420 -0.475040  0.590195
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.255923 -0.892860 -2.929329
# b  0.980613 -0.352598 -0.043042
# c  0.980613 -0.352598 -0.043042
# d -2.241967  0.884888  0.488211
# e -0.698420 -0.475040  0.590195
# f -0.698420 -0.475040  0.590195
